# %% [markdown]
# <a href="https://colab.research.google.com/github/MissLolaDavid/Assignement-7/blob/main/Copy_of_Classwork_Lola_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def phone_book():
    action = True
    while action:
        operation= input('''
            Select Options:
                [1] List Phone Numbers
                [2] Add Contact
                [3] Remove Contact
                [4] Update Contact
                [5] Lookup Contact by Number
                [6] Quit
                         ''')
        if operation =='1':       #List contacts
            with open ("/content/phonebook.txt", "r") as file:
                print(file.read())
            
                
        elif operation =='2':     #add contact
            ans = input ("Do you have any contacts in your phonebook? y/n")
            if ans == 'n':
              index = 1
            elif ans == 'y':
              index =0
              #lists the number of contacts to count number of contacts
              with open ("/content/phonebook.txt", "r") as file:
                contents = file.read()
                contact_list = contents.split("\n")

                for i in contact_list:
                 index=index+1

            str_action="y"
            my_contacts={}
            
            while str_action == "y":
                #Create an empty dictionary to hold phone details
                my_contacts = {index:{"First Name":[], "Middle Name":[], "Last Name":[], "Mailing Address":[], "Country":[], 
                                    "City":[], "Zip Code":[], "Email Address":[], "Phone Number":[]}}
                #prompt for the contacts to be entered
                FirstName = input("Enter the First Name: ")
                MiddleName = input("Enter the Middle Name: ")
                LastName = input("Enter the Last Name: ")
                MailingAddress = input("Enter the Mailing Address: ")
                Country = input("Enter the Country: ")
                City = input("Enter the City: ")
                ZipCode = input("Enter the Zip Code: ")
                EmailAddress = input("Enter the Email Address: ")
                PhoneNumber = input("Enter the Phone Number: ")

                #Add value to dictionary.
                my_contacts[index]["First Name"]= FirstName
                my_contacts[index]["Middle Name"] = MiddleName
                my_contacts[index]["Last Name"]= LastName
                my_contacts[index]["Mailing Address"] = MailingAddress
                my_contacts[index]["Country"] = Country
                my_contacts[index]["City"] = City
                my_contacts[index]["Zip Code"] = ZipCode
                my_contacts[index]["Email Address"] = EmailAddress
                my_contacts[index]["Phone Number"] = PhoneNumber
                print(my_contacts)

                #Open the Contacts file to save details of phone book
                with open ("/content/phonebook.txt", "a") as file:
                    for key, value in my_contacts.items():
                        file.write('%s-%s\n' % (key, value))
                        print("Record saved successfully")
                index = index +1
                str_action=input("Do you want to create a new contact? (y/n): ")
            else:
                print ("Invalid input")
                
            
                
        elif operation =='3':     #Remove contact
            contact_to_del = {}
            with open ("/content/phonebook.txt", "r") as file:
                for line in file:
                  (key, val) = line.split("-")
                  contact_to_del[int(key)] = val
                  
                del_str=int(input("Enter Record Number to remove: "))
                contact_to_del.pop (del_str)
                print ("Contact deleted")
                print("New Contact List:")
                print(contact_to_del)
        

        
        elif operation =='4':  # Updating of the phonebook
            contact_to_update = {}
            with open ("/content/phonebook.txt", "r") as file:
                for line in file:
                  (key, val) = line.split("-")
                  contact_to_update[int(key)] = val

              #contacts = file.readlines{}
                
                upd_key =int(input("Enter Record Number to update: "))
                contact_to_update.pop (upd_key)

                 #Create an empty dictionary to hold phone details
               
                #prompt for the contacts for update to be entered
                FirstName = input("Enter the First Name: ")
                MiddleName = input("Enter the Middle Name: ")
                LastName = input("Enter the Last Name: ")
                MailingAddress = input("Enter the Mailing Address: ")
                Country = input("Enter the Country: ")
                City = input("Enter the City: ")
                ZipCode = input("Enter the Zip Code: ")
                EmailAddress = input("Enter the Email Address: ")
                PhoneNumber = input("Enter the Phone Number: ")

                contact_to_update[upd_key] = ':{"First Name": ' + FirstName + ' "Middle Name": ' + MiddleName + ', "Last Name": ' + LastName + ' "Mailing Address": ' + MailingAddress + ', "Country": ' + Country + ', "City": ' + City + ', "Zip Code": ' + ZipCode + ', "Email Address": ' + EmailAddress + ', "Phone Number": ' + PhoneNumber+'}:'
                
                #Add value to dictionary.
                #contact_to_update[upd_key]["First Name"] = FirstName
                #contact_to_update[upd_key]["Middle Name"] = MiddleName 
                #contact_to_update[upd_key]["Last Name"] = LastName
                #contact_to_update[upd_key]["Mailing Address"] = MailingAddress
                #contact_to_update[upd_key]["Country"] = Country
                #contact_to_update[upd_key]["City"] = City
                #contact_to_update[upd_key]["Zip Code"] = ZipCode
                #contact_to_update[upd_key]["Email Address"] = EmailAddress
                #contact_to_update[upd_key]["Phone Number"] = PhoneNumber
                print(contact_to_update.items())

        
                #Open the Contacts file to save details of phone book
                with open ("/content/phonebook.txt", "w") as file:
                    for key, value in contact_to_update.items():
                        file.write('%s-%s\n' % (key, value))
                        print("Record saved successfully")
        
          
        elif operation =='5': 
            contact_to_search = {}
            with open ("/content/phonebook.txt", "r") as file:
                for line in file:
                  (key, val) = line.split("-")
                  contact_to_search[int(key)] = val
                
                search_key =int(input("Enter Record Number to Search: "))
          
                print(contact_to_search[search_key])  #Search
        
        elif operation == '6':
          print ("You have just quit the program")
          action = False
        else:
          6
          
          print ("Invalid input")

phone_book()
# Out:
#             Select Options:
#                 [1] List Phone Numbers
#                 [2] Add Contact
#                 [3] Remove Contact
#                 [4] Update Contact
#                 [5] Lookup Contact by Number
#                 [6] Quit
#                          1
# 1-{'First Name': 'Lola', 'Middle Name': 'Muthoni', 'Last Name': 'David', 'Mailing Address': '12345', 'Country': 'Kenya', 'City': 'Nairobi', 'Zip Code': '12345', 'Email Address': 'lolamuthoni@gmail.com', 'Phone Number': '0711890609'}
#
# 3-{'First Name': 'Courage', 'Middle Name': 'Cowardly', 'Last Name': 'Dog', 'Mailing Address': '45678', 'Country': 'U.S.A', 'City': 'Middle of Nowhere', 'Zip Code': '45678', 'Email Address': 'courage@cartoonnetwork.com', 'Phone Number': '+3456890632'}
#
# 2-:{"First Name": ED "Middle Name": EDD, "Last Name": EDDY "Mailing Address": 234567, "Country": USA, "City": Texas, "Zip Code": 34567, "Email Address": eddy@cartoonnetwork.com, "Phone Number": +1434235436346}:
#
#
# ...
